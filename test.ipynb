# %%
from pathlib import Path
from src.datasets import CrossDockDataset
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
test_dataset = CrossDockDataset(
    data_path="data/single_backup",
    prefix="crossdocksingle_test_full",
    device=device,
)

# %%
path_to_data = Path.cwd() / "data" / "single" / "test_jean"

# %%
# for obj in test_dataset:
#     torch.save(obj, Path(path_to_data, f"mol_{obj['uuid']}.pt"))

# %%
l = []
for path in path_to_data.rglob("*"):
    l.append(path)

# %%
len(l)
# Out:
# 43

# %%
root = path_to_data
file_paths = []
for path in path_to_data.glob("*"):
    if path.suffix == ".pt":
        file_paths.append(path)

# %%
# Out:
# 76108
